# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
        'Name': ['Ali', 'Sara', 'Zain', 'Fatima', 'Usman'],
        'Age': [25, 30, None, 22, 28],
        'Salary': [50000, 60000, 55000, None, 70000]
}

# %%
df = pd.DataFrame(data)
print("Orginal data:")
print(df)
# Out:
# Orginal data:
#      Name   Age   Salary
# 0     Ali  25.0  50000.0
# 1    Sara  30.0  60000.0
# 2    Zain   NaN  55000.0
# 3  Fatima  22.0      NaN
# 4   Usman  28.0  70000.0

# %%
print("---data information--")
df.info()
# Out:
# ---data information--
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     4 non-null      float64
#  2   Salary  4 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 248.0+ bytes

# %%
print("\n ---Missing Values count---")
missing_values = df.isnull().sum()
print(missing_values)
# Out:
#  ---Missing Values count---
# Name      0
# Age       1
# Salary    1
# dtype: int64

# %%
mean_age = df['Age'].mean()
df['Age'] = df['Age'].fillna(mean_age)

mean_salary = df['Salary'].mean()
df['Salary'] = df['Salary'].fillna(mean_salary)

print("---cleaned data---")
print(df)
# Out:
# ---cleaned data---
#      Name    Age   Salary
# 0     Ali  25.00  50000.0
# 1    Sara  30.00  60000.0
# 2    Zain  26.25  55000.0
# 3  Fatima  22.00  58750.0
# 4   Usman  28.00  70000.0

# %%
plt.figure(figsize=(8, 5))
plt.bar(df['Name'], df['Salary'], color='skyblue')

plt.title('Empolyees Salary Comparison')
plt.xlabel('Employee name')
plt.ylabel('Salary (PKR)')

plt.show()

# %%
pwd
# Out:
# 'C:\\Users\\Admin'
